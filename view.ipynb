# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
if not 'build' in sys.path:
    sys.path.append('build')
import pyising

# %%
# Read the CSV file
df = pd.read_csv('result.csv')

df.plot('time', 'energy')
df.plot('time', 'magnetization')

spins = pd.read_csv("spins.csv")
spins.plot.scatter('x','y', c='spin', colormap='rainbow', vmin=-1, vmax=1, s=200)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
for _ in range(1000):
    result = pyising.run(0.1, 0.1, 100000)
    print(result.energy, result.magnetization)
# Out:
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# -1640.0000000000002 400.0
# ...
